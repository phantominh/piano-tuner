# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

# %%
filename = "scale_7.wav"
# Load in audio file
buffer, sample_rate = librosa.load(filename)
print(sample_rate)
# Out:
# 22050

# %%
# Construct graph that represents the linear magnitude of audio buffer on time domain
librosa.display.waveplot(buffer, sr=sample_rate)

# %%
# Construct graphs that visualize smaller ranges of audio buffer
librosa.display.waveplot(buffer[:int(sample_rate/50)], sr=sample_rate)

# %%
# Transform data into time-frequency-magnitude dimension.
stft_buffer = abs(librosa.stft(buffer, n_fft=4096, hop_length=4096))

# Convert magnitude to decibal scale
# db = librosa.amplitude_to_db(np.abs(stft_buffer), ref=np.max)
stft_buffer
# Out:
# array([[9.7055839e-05, 1.3856336e-05, 6.0554234e-05, ..., 5.8022237e-01,
#         1.7028962e-01, 5.5696547e-01],
#        [8.0630401e-05, 1.6472684e-05, 4.1250041e-05, ..., 1.9404283e-01,
#         1.1138306e+00, 1.2712168e+00],
#        [1.2179548e-05, 3.1080854e-05, 3.5072266e-05, ..., 1.9627846e+00,
#         1.0104909e+00, 1.8792856e+00],
#        ...,
#        [9.2176037e-07, 6.8000480e-07, 2.7060827e-07, ..., 2.5027828e-07,
#         6.4076886e-07, 1.0597868e-06],
#        [9.6722692e-07, 9.5616213e-07, 2.6800237e-07, ..., 5.7587789e-07,
#         1.0730862e-07, 8.7410530e-07],
#        [6.7882110e-07, 1.2128860e-06, 1.3434327e-07, ..., 4.0152381e-07,
#         5.5547150e-07, 8.2446388e-07]], dtype=float32)

# %%
fig, ax = plt.subplots()
img = librosa.display.specshow(stft_buffer, x_axis='time', y_axis='linear', ax=ax)
ax.set_ylim([1945, 2140]) # C7 range
# ax.set_ylim([0, 1000])
ax.set(title='Using a linear frequency axis')
fig.colorbar(img, ax=ax, format="%2.f")

# %%
num_freq_bin, num_frame = stft_buffer.shape # The number of frames of the stft data
print(num_freq_bin)
print(num_frame)
# Out:
# 2049
# 95

# %%
sample_freq_arr = librosa.fft_frequencies(sr=sample_rate, n_fft=4096)
sample_freq_arr

bin_range = sample_freq_arr[1]

bin_range
# Out:
# 5.38330078125

# %%
for t in range(0, num_frame):
    max_freq = 0
    max_magnitude = 0
    for f in range(0, num_freq_bin):
        if (max_magnitude < np.abs(stft_buffer[f, t])):
            max_magnitude = np.abs(stft_buffer[f, t])
            max_freq = f
    print(max_freq*bin_range)
    print(librosa.hz_to_note(max_freq*bin_range))
# Out:
# 8327.96630859375
# C9
# 8839.3798828125
# C♯9
# 8737.09716796875
# C♯9
# 8554.06494140625
# C9
# 8839.3798828125
# C♯9
# 9953.72314453125
# D♯9
# 9043.9453125
# C♯9
# 10072.15576171875
# D♯9
# 9022.412109375
# C♯9
# 9953.72314453125
# D♯9
# 10125.98876953125
# D♯9
# 258.3984375
# C4
# 258.3984375
# C4
# 263.78173828125
# C4
# 522.18017578125
# C5
# 263.78173828125
# C4
# 522.18017578125
# C5
# 1049.74365234375
# C6
# 522.18017578125
# C5
# 522.18017578125
# C5
# 522.18017578125
# C5
# 522.18017578125
# C5
# 586.77978515625
# D5
# 586.77978515625
# D5
# 586.77978515625
# D5
# 586.77978515625
# D5
# 296.08154296875
# D4
# 290.6982421875
# D4
# 586.77978515625
# D5
# 586.77978515625
# D5
# 586.77978515625
# D5
# 586.77978515625
# D5
# 586.77978515625
# D5
# 328.38134765625
# E4
# 656.7626953125
# E5
# 328.38134765625
# E4
# 656.7626953125
# E5
# 656.7626953125
# E5
# 328.38134765625
# E4
# 328.38134765625
# E4
# 328.38134765625
# E4
# 656.7626953125
# E5
# 656.7626953125
# E5
# 349.91455078125
# F4
# 349.91455078125
# F4
# 349.91455078125
# F4
# 349.91455078125
# F4
# 349.91455078125
# F4
# 699.8291015625
# F5
# 699.8291015625
# F5
# 699.8291015625
# F5
# 699.8291015625
# F5
# 699.8291015625
# F5
# 699.8291015625
# F5
# 392.98095703125
# G4
# 392.98095703125
# G4
# 392.98095703125
# G4
# 392.98095703125
# G4
# 392.98095703125
# G4
# 1970.2880859375
# B6
# 392.98095703125
# G4
# 785.9619140625
# G5
# 785.9619140625
# G5
# 785.9619140625
# G5
# 785.9619140625
# G5
# 441.4306640625
# A4
# 441.4306640625
# A4
# 441.4306640625
# A4
# 441.4306640625
# A4
# 441.4306640625
# A4
# 441.4306640625
# A4
# 441.4306640625
# A4
# 441.4306640625
# A4
# 441.4306640625
# A4
# 441.4306640625
# A4
# 436.04736328125
# A4
# 495.263671875
# B4
# 495.263671875
# B4
# 495.263671875
# B4
# 495.263671875
# B4
# 495.263671875
# B4
# 495.263671875
# B4
# 495.263671875
# B4
# 495.263671875
# B4
# 495.263671875
# B4
# 495.263671875
# B4
# 522.18017578125
# C5
# 522.18017578125
# C5
# 522.18017578125
# C5
# 522.18017578125
# C5
# 522.18017578125
# C5
# 522.18017578125
# C5
# 522.18017578125
# C5
# 522.18017578125
# C5
# 522.18017578125
# C5

# %%
# Pitch detection approaches: https://en.wikipedia.org/wiki/Pitch_detection_algorithm
# TODO: Handle echos and background sounds
# https://www.audiology.org/sites/default/files/ChasinConversionChart.pdf

# %%
# https://www.audiolabs-erlangen.de/content/05-fau/professor/00-mueller/02-teaching/2016w_mpa/LabCourse_HPSS.pdf
H, P = librosa.decompose.hpss(stft_buffer)
H
# Out:
# array([[5.19145624e-06, 2.24649120e-05, 6.47541415e-03, 1.23264603e-04,
#         2.53031659e-03, 4.81776847e-03],
#        [4.59184002e-06, 4.95281529e-05, 4.50525507e-02, 4.75493871e-04,
#         7.15400500e-04, 3.26197944e-03],
#        [8.03770547e-07, 1.34579794e-04, 1.02903776e-01, 1.71293924e-03,
#         4.01339447e-03, 6.77362224e-03],
#        ...,
#        [4.68906501e-06, 9.43553971e-07, 5.39604207e-06, 3.70300677e-06,
#         3.82261396e-06, 3.79708975e-09],
#        [2.96400231e-06, 1.15085652e-06, 3.18490993e-06, 4.00815134e-06,
#         2.56923590e-06, 5.28412203e-09],
#        [3.87466889e-06, 1.26139969e-06, 2.84243379e-06, 1.20475272e-06,
#         8.68322957e-07, 2.99705327e-09]], dtype=float32)

# %%
fig, ax = plt.subplots()
img = librosa.display.specshow(H, x_axis='time', y_axis='linear', ax=ax)
ax.set_ylim([1945, 2140]) # C7 range
# ax.set_ylim([0, 1000])
ax.set(title='Using a linear frequency axis')
fig.colorbar(img, ax=ax, format="%2.f")

# %%
for t in range(0, num_frame):
    max_freq = 0
    max_magnitude = 0
    for f in range(0, num_freq_bin):
        if (max_magnitude < np.abs(H[f, t])):
            max_magnitude = np.abs(H[f, t])
            max_freq = f
    print(max_freq*bin_range)
    print(librosa.hz_to_note(max_freq*bin_range))
# Out:
# 9140.8447265625
# D9
# 9420.7763671875
# D9
# 2094.10400390625
# C7
# 2104.87060546875
# C7
# 2094.10400390625
# C7
# 2099.4873046875
# C7
